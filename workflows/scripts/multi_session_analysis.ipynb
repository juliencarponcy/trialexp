# %% [markdown]
# # Multi-session analysis
# This notebook demonstrate how to combine different xarray dataset together and perform group-level analysis

# %%
import xarray as xr
import matplotlib.pylab as plt
import seaborn as sns
from pathlib import Path
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ## Loading data

# %%
dataaset = xr.open_mfdataset('Z:\\Teris\\ASAP\\expt_sessions\\RE603*\\processed\\xr_session.nc',
                             combine='nested', engine='h5netcdf')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dataaset = xr.open_mfdataset('Z:\\Teris\\ASAP\\expt_sessions\\RE*\\processed\\xr_session.nc',
#       2                              combine='nested', engine='h5netcdf')
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\backends\api.py:1013, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1009 try:
#    1010     if combine == "nested":
#    1011         # Combined nested list by successive concat and merge operations
#    1012         # along each dimension, using structure given by "ids"
# -> 1013         combined = _nested_combine(
#    1014             datasets,
#    1015             concat_dims=concat_dim,
#    1016             compat=compat,
#    1017             data_vars=data_vars,
#    1018             coords=coords,
#    1019             ids=ids,
#    1020             join=join,
#    1021             combine_attrs=combine_attrs,
#    1022         )
#    1023     elif combine == "by_coords":
#    1024         # Redo ordering from coordinates, ignoring how they were ordered
#    1025         # previously
#    1026         combined = combine_by_coords(
#    1027             datasets,
#    1028             compat=compat,
#    (...)
#    1032             combine_attrs=combine_attrs,
#    1033         )
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\combine.py:365, in _nested_combine(datasets, concat_dims, compat, data_vars, coords, ids, fill_value, join, combine_attrs)
#     362 _check_shape_tile_ids(combined_ids)
#     364 # Apply series of concatenate or merge operations along each dimension
# --> 365 combined = _combine_nd(
#     366     combined_ids,
#     367     concat_dims,
#     368     compat=compat,
#     369     data_vars=data_vars,
#     370     coords=coords,
#     371     fill_value=fill_value,
#     372     join=join,
#     373     combine_attrs=combine_attrs,
#     374 )
#     375 return combined
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\combine.py:239, in _combine_nd(combined_ids, concat_dims, data_vars, coords, compat, fill_value, join, combine_attrs)
#     235 # Each iteration of this loop reduces the length of the tile_ids tuples
#     236 # by one. It always combines along the first dimension, removing the first
#     237 # element of the tuple
#     238 for concat_dim in concat_dims:
# --> 239     combined_ids = _combine_all_along_first_dim(
#     240         combined_ids,
#     241         dim=concat_dim,
#     242         data_vars=data_vars,
#     243         coords=coords,
#     244         compat=compat,
#     245         fill_value=fill_value,
#     246         join=join,
#     247         combine_attrs=combine_attrs,
#     248     )
#     249 (combined_ds,) = combined_ids.values()
#     250 return combined_ds
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\combine.py:275, in _combine_all_along_first_dim(combined_ids, dim, data_vars, coords, compat, fill_value, join, combine_attrs)
#     273     combined_ids = dict(sorted(group))
#     274     datasets = combined_ids.values()
# --> 275     new_combined_ids[new_id] = _combine_1d(
#     276         datasets, dim, compat, data_vars, coords, fill_value, join, combine_attrs
#     277     )
#     278 return new_combined_ids
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\combine.py:320, in _combine_1d(datasets, concat_dim, compat, data_vars, coords, fill_value, join, combine_attrs)
#     318             raise
#     319 else:
# --> 320     combined = merge(
#     321         datasets,
#     322         compat=compat,
#     323         fill_value=fill_value,
#     324         join=join,
#     325         combine_attrs=combine_attrs,
#     326     )
#     328 return combined
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\merge.py:1025, in merge(objects, compat, join, fill_value, combine_attrs)
#    1022     obj = obj.to_dataset(promote_attrs=True) if isinstance(obj, DataArray) else obj
#    1023     dict_like_objects.append(obj)
# -> 1025 merge_result = merge_core(
#    1026     dict_like_objects,
#    1027     compat,
#    1028     join,
#    1029     combine_attrs=combine_attrs,
#    1030     fill_value=fill_value,
#    1031 )
#    1032 return Dataset._construct_direct(**merge_result._asdict())
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\merge.py:757, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     755 collected = collect_variables_and_indexes(aligned, indexes=indexes)
#     756 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
# --> 757 variables, out_indexes = merge_collected(
#     758     collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     759 )
#     761 dims = calculate_dimensions(variables)
#     763 coord_names, noncoord_names = determine_coords(coerced)
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\merge.py:302, in merge_collected(grouped, prioritized, compat, combine_attrs, equals)
#     300 variables = [variable for variable, _ in elements_list]
#     301 try:
# --> 302     merged_vars[name] = unique_variable(
#     303         name, variables, compat, equals.get(name, None)
#     304     )
#     305 except MergeError:
#     306     if compat != "minimal":
#     307         # we need more than "minimal" compatibility (for which
#     308         # we drop conflicting coordinates)
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\merge.py:156, in unique_variable(name, variables, compat, equals)
#     153                 break
#     155 if not equals:
# --> 156     raise MergeError(
#     157         f"conflicting values for variable {name!r} on objects to be combined. "
#     158         "You can skip this check by specifying compat='override'."
#     159     )
#     161 if combine_method:
#     162     for var in variables[1:]:
#
# MergeError: conflicting values for variable 'trial_nb' on objects to be combined. You can skip this check by specifying compat='override'.

# %%
f1 = r'Z:/Teris/ASAP/expt_sessions/RE603-2023-03-24-083953/processed/xr_session.nc'
f2 = r'Z:/Teris/ASAP/expt_sessions/RE603-2023-03-21-152900/processed/xr_session.nc'

d1= xr.open_dataset(f1)
d2  = xr.open_dataset(f2)

# %%
from glob import glob
fns = glob(r'Z:/Teris/ASAP/expt_sessions/kms064*/processed/xr_session.nc')

# %%
session_id = []

ds_all =[]

for fn in tqdm(fns):
    ds = xr.open_dataset(fn)
    ds_all.append(ds)
    session_id.append(Path(fn).parent.parent.name)
# Out:
# 100%|██████████| 22/22 [00:11<00:00,  1.96it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\dataset.py:1348, in Dataset._construct_dataarray(self, name)
#    1347 try:
# -> 1348     variable = self._variables[name]
#    1349 except KeyError:
#
# KeyError: 'break_after_abort'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\concat.py:561, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     560 try:
# --> 561     vars = ensure_common_dims([ds[name].variable for ds in datasets])
#     562 except KeyError:
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\concat.py:561, in <listcomp>(.0)
#     560 try:
# --> 561     vars = ensure_common_dims([ds[name].variable for ds in datasets])
#     562 except KeyError:
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\dataset.py:1439, in Dataset.__getitem__(self, key)
#    1438 if utils.hashable(key):
# -> 1439     return self._construct_dataarray(key)
#    1440 if utils.iterable_of_hashable(key):
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\dataset.py:1350, in Dataset._construct_dataarray(self, name)
#    1349 except KeyError:
# -> 1350     _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1352 needed_dims = set(variable.dims)
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\dataset.py:186, in _get_virtual_variable(variables, key, dim_sizes)
#     185 if len(split_key) != 2:
# --> 186     raise KeyError(key)
#     188 ref_name, var_name = split_key
#
# KeyError: 'break_after_abort'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 10
#       7     ds_all.append(ds)
#       8     session_id.append(Path(fn).parent.parent.name)
# ---> 10 ds_combined = xr.concat(ds_all, pd.Index(session_id, name='session_id'))
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\concat.py:248, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     236     return _dataarray_concat(
#     237         objs,
#     238         dim=dim,
#    (...)
#     245         combine_attrs=combine_attrs,
#     246     )
#     247 elif isinstance(first_obj, Dataset):
# --> 248     return _dataset_concat(
#     249         objs,
#     250         dim=dim,
#     251         data_vars=data_vars,
#     252         coords=coords,
#     253         compat=compat,
#     254         positions=positions,
#     255         fill_value=fill_value,
#     256         join=join,
#     257         combine_attrs=combine_attrs,
#     258     )
#     259 else:
#     260     raise TypeError(
#     261         "can only concatenate xarray Dataset and DataArray "
#     262         f"objects, got {type(first_obj)}"
#     263     )
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\concat.py:563, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     561     vars = ensure_common_dims([ds[name].variable for ds in datasets])
#     562 except KeyError:
# --> 563     raise ValueError(f"{name!r} is not present in all datasets.")
#     565 # Try concatenate the indexes, concatenate the variables when no index
#     566 # is found on all datasets.
#     567 indexes: list[Index] = list(get_indexes(name))
#
# ValueError: 'break_after_abort' is not present in all datasets.

# %%
ds_combined = xr.concat(ds_all, pd.Index(session_id, name='session_id'), data_vars=['analog_1_df_over_f'])
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 ds_combined = xr.concat(ds_all, pd.Index(session_id, name='session_id'), data_vars='minimal')
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\concat.py:248, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     236     return _dataarray_concat(
#     237         objs,
#     238         dim=dim,
#    (...)
#     245         combine_attrs=combine_attrs,
#     246     )
#     247 elif isinstance(first_obj, Dataset):
# --> 248     return _dataset_concat(
#     249         objs,
#     250         dim=dim,
#     251         data_vars=data_vars,
#     252         coords=coords,
#     253         compat=compat,
#     254         positions=positions,
#     255         fill_value=fill_value,
#     256         join=join,
#     257         combine_attrs=combine_attrs,
#     258     )
#     259 else:
#     260     raise TypeError(
#     261         "can only concatenate xarray Dataset and DataArray "
#     262         f"objects, got {type(first_obj)}"
#     263     )
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\concat.py:509, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     503 if variables_to_merge:
#     504     grouped = {
#     505         k: v
#     506         for k, v in collect_variables_and_indexes(list(datasets)).items()
#     507         if k in variables_to_merge
#     508     }
# --> 509     merged_vars, merged_indexes = merge_collected(
#     510         grouped, compat=compat, equals=equals
#     511     )
#     512     result_vars.update(merged_vars)
#     513     result_indexes.update(merged_indexes)
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\merge.py:302, in merge_collected(grouped, prioritized, compat, combine_attrs, equals)
#     300 variables = [variable for variable, _ in elements_list]
#     301 try:
# --> 302     merged_vars[name] = unique_variable(
#     303         name, variables, compat, equals.get(name, None)
#     304     )
#     305 except MergeError:
#     306     if compat != "minimal":
#     307         # we need more than "minimal" compatibility (for which
#     308         # we drop conflicting coordinates)
#
# File c:\Users\ndcn1330\AppData\Local\miniconda3\envs\trialexp\lib\site-packages\xarray\core\merge.py:156, in unique_variable(name, variables, compat, equals)
#     153                 break
#     155 if not equals:
# --> 156     raise MergeError(
#     157         f"conflicting values for variable {name!r} on objects to be combined. "
#     158         "You can skip this check by specifying compat='override'."
#     159     )
#     161 if combine_method:
#     162     for var in variables[1:]:
#
# MergeError: conflicting values for variable 'trial_nb' on objects to be combined. You can skip this check by specifying compat='override'.

# %%
ds_combined
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 668560, session_id: 15)
# Coordinates:
#   * time                     (time) float64 1.78e+04 1.785e+04 ... 3.686e+06
#   * session_id               (session_id) object 'RE602-2023-03-16-091935' .....
# Data variables: (12/26)
#     trial_nb                 (session_id, time) float64 nan nan ... 275.0 275.0
#     uid                      (session_id, time) object nan ... 'RE604_2023-03...
#     trigger                  (session_id, time) object nan ... 'hold_for_water'
#     valid                    (session_id, time) float64 nan nan nan ... 1.0 1.0
#     break_after_abort        (session_id, time) float64 nan nan nan ... 0.0 0.0
#     US_end_timer             (session_id, time) float64 nan nan nan ... 1.0 1.0
#     ...                       ...
#     analog_1_filt            (session_id, time) float64 nan nan ... 0.5616
#     analog_2_filt            (session_id, time) float64 nan nan ... 3.316 3.316
#     analog_1_df_over_f       (session_id, time) float64 nan nan ... 1.002 1.0
#     rel_time_hold_for_water  (session_id, time) float64 nan nan nan ... nan nan
#     rel_time_first_bar_off   (session_id, time) float64 nan nan nan ... nan nan
#     rel_time_spout           (session_id, time) float64 nan nan nan ... nan nan
# Attributes: (12/19)
#     pulse_inds_1:         []
#     pulse_inds_2:         [   9674   15648   24450   32623   36322   45442   ...
#     pulse_times_1:        []
#     pulse_times_2:        [   9674.   15648.   24450.   32623.   36322.   454...
#     subject_ID:           RE602
#     date_time:            2023-03-16T09:19:20
#     ...                   ...
#     Task file hash:       2536334725
#     Setup ID:             COM3
#     Framework version:    1.8.1
#     Micropython version:  1.13
#     Subject ID:           RE602
#     Start date:           2023/03/16 09:19:35

# %%
df2plot=ds_combined[['rel_time_spout','analog_1_df_over_f','success']].to_dataframe().reset_index()

# %%
# fig, ax = plt.subplots(1,1,dpi=300, figsize=(6,6))

ax = sns.lineplot(x='rel_time_spout',hue='success',
            y='analog_1_df_over_f', data=df2plot)
