# %%
from pathlib import Path
import pandas as pd 
from trialexp.process.pycontrol.event_filters import extract_event_time, get_first_spout

# %% [markdown]
# ## Loading data

# %%
# Load the event dataframe from the pipeline

#data path, you need to change it to the correct path on your computer
path = Path('/home/MRC.OX.AC.UK/ndcn1330/ettin/Julien/Data/head-fixed/by_sessions/reaching_go_spout_bar_nov22/RE604-2023-03-24-091134/processed/df_events_cond.pkl')
df_event = pd.read_pickle(path)

#an overview of the dataframe structure
df_event.head()
# Out:
#     type               name     time value  trial_nb  trial_time  \
# 0  state     hold_for_water  14355.0   NaN       1.0         0.0
# 1  event            bar_off  14678.0   NaN       1.0       323.0
# 2  state  break_after_abort  14678.0   NaN       1.0       323.0
# 3  event                bar  14700.0   NaN       1.0       345.0
# 4  event            bar_off  15374.0   NaN       1.0      1019.0
#
#         trigger_x                          uid       trigger_y  valid  ...  \
# 0  hold_for_water  RE604_2023-03-24_09:11:34_1  hold_for_water   True  ...
# 1  hold_for_water  RE604_2023-03-24_09:11:34_1  hold_for_water   True  ...
# 2  hold_for_water  RE604_2023-03-24_09:11:34_1  hold_for_water   True  ...
# 3  hold_for_water  RE604_2023-03-24_09:11:34_1  hold_for_water   True  ...
# 4  hold_for_water  RE604_2023-03-24_09:11:34_1  hold_for_water   True  ...
#
#    water_on  water by bar_off  water by spout  water for free  water success  \
# 0     False             False           False           False          False
# 1     False             False           False           False          False
# 2     False             False           False           False          False
# 3     False             False           False           False          False
# 4     False             False           False           False          False
#
#    busy_win_timer  spout  button_press  waiting_for_spout  success
# 0           False  False         False              False    False
# 1           False  False         False              False    False
# 2           False  False         False              False    False
# 3           False  False         False              False    False
# 4           False  False         False              False    False
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Writing the event extraction function

# %%
df_trial = df_event[df_event.trial_nb==2] #selecting one trial from all the events

def get_spout(df_trial):
    #df_trial is a dataframe of a single trial
    # it needs to return a row of original dataframe
    spout =  df_trial[df_trial['name']=='spout']
    
    if len(spout) >0:
        return spout.iloc[0]

get_spout(df_trial)
# Out:
# type                                       event
# name                                       spout
# time                                     41567.0
# value                                        NaN
# trial_nb                                     2.0
# trial_time                                1955.0
# trigger_x                         hold_for_water
# uid                  RE604_2023-03-24_09:11:34_2
# trigger_y                         hold_for_water
# valid                                       True
# break_after_abort                           True
# US_end_timer                               False
# water_on                                   False
# water by bar_off                           False
# water by spout                             False
# water for free                             False
# water success                              False
# busy_win_timer                             False
# spout                                       True
# button_press                               False
# waiting_for_spout                          False
# success                                    False
# Name: 25, dtype: object

# %% [markdown]
# ## Actual usage in pipeline

# %%
extract_event_time(df_event, get_spout, {})
# Out:
# trial_nb
# 1.0            NaN
# 2.0        41567.0
# 3.0        49390.0
# 4.0            NaN
# 5.0            NaN
#            ...
# 273.0    3529983.0
# 274.0          NaN
# 275.0    3555524.0
# 276.0          NaN
# 277.0    3582602.0
# Name: time, Length: 277, dtype: float64
