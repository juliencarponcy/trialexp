# %% [markdown]
# ## Workflow to analyze DeepLabCut data

# %% [markdown]
# ### Imports

# %%
# Import Session and Experiment class with helper functions
# %load_ext autoreload
# %autoreload 2 

# Import Session and Experiment class with helper functions
from trialexp.process.data_import import *
from trialexp.utils.DLC_utilities import *
from trialexp.utils.pyphotometry_utilities import *

# %% [markdown]
# ### Variables

# %%
import pandas as pd

trial_window = [-2000, 6000] # in ms

# time limit around trigger to perform an event
# determine successful trials
timelim = [0, 4000] # in ms

# Digital channel nb of the pyphotometry device
# on which rsync signal is sent (from pycontrol device)
rsync_chan = 2

basefolder, _ = os.path.split(os.getcwd())

# These must be absolute paths
# use this to use within package tasks files (in params)
tasksfile = os.path.join(Path(basefolder).parent,'params/tasks_params.csv')
# use this to put a local full path
#tasksfile = -r'C:/.../tasks_params.csv' 

photometry_dir = r'\\ettin\Magill_Lab\Julien\Data\head-fixed\test_folder\delayed_go\pyphotometry\delayed_go_dual_2022'
pycontrol_dir = r'\\ettin\Magill_Lab\Julien\Data\head-fixed\test_folder\delayed_go\pycontrol'

video_dir = r'\\ettin\Magill_Lab\Julien\Data\head-fixed\videos'

# %% [markdown]
# ### Tasks
# - A tasks definition file (.csv) contains all the information to perform the extractions of behaviorally relevant information from **PyControl** files, for each **task** file. It includes what are the **triggers** of different trial types, what **events** to extract (with time data), and what are events or printed lines that could be relevant to determine the **conditions** (e.g: free reward, optogenetic stimulation type, etc.)
# - To analyze a new task you need to append task characteristics like **task** filename, **triggers**, **events** and **conditions**

# %%
tasks = pd.read_csv(tasksfile, usecols = [1,2,3,4], index_col = False)
tasks
# Out:
#                                            task                      triggers  \
# 0                                  lick_go_nogo                      go; nogo
# 1                   lick_go_nogo_unconditionned                      go; nogo
# 2              lick_go_nogo_unconditionned_opto                      go; nogo
# 3                              reaching_go_nogo                CS_Go; CS_NoGo
# 4                           reaching_go_nogo_jc             CS_plus; CS_minus
# 5              reaching_go_nogo_opto_continuous                CS_Go; CS_NoGo
# 6                reaching_go_nogo_opto_sinusoid                CS_Go; CS_NoGo
# 7          reaching_go_nogo_opto_sinusoid_spout                CS_Go; CS_NoGo
# 8                     reaching_go_nogo_reversal                CS_Go; CS_NoGo
# 9           reaching_go_nogo_reversal_incentive                CS_Go; CS_NoGo
# 10                 reaching_go_nogo_touch_spout                CS_Go; CS_NoGo
# 11                                reaching_test                    us_deliver
# 12                             reaching_test_CS             CS_plus; CS_minus
# 13                                  reaching_yp           reward_presentation
# 14                   train_CSgo_US_coterminated                            Go
# 15                     train_Go_CS-US_pavlovian                            Go
# 16            train_Go_CS-US_pavlovian_with_bar                         CS_Go
# 17                reaching_go_spout_cued_uncued                         CS_Go
# 18                      pavlovian_nobar_nodelay                         CS_Go
# 19                            cued_uncued_oct22                  Cued; UnCued
# 20                        go_rewarding_aversive              Go_water; Go_air
# 21                      reaching_go_spout_nov22                    hold_timer
# 22              reaching_go_spout_nov22_timewin                hold_for_water
# 23                  reaching_go_spout_bar_nov22                hold_for_water
# 24             reaching_go_spout_bar_dual_dec22                hold_for_water
# 25  reaching_go_spout_bar_dual_all_reward_dec22  hold_for_water; hold_for_air
#
#                                                events  \
# 0                                 bar; bar_off; spout
# 1                                 bar; bar_off; spout
# 2                                 bar; bar_off; spout
# 3                                 bar; bar_off; spout
# 4                                 bar; bar_off; spout
# 5                                 bar; bar_off; spout
# 6                                 bar; bar_off; spout
# 7                                 bar; bar_off; spout
# 8                                 bar; bar_off; spout
# 9                                 bar; bar_off; spout
# 10                                bar; bar_off; spout
# 11                                bar; bar_off; spout
# 12                                bar; bar_off; spout
# 13                                bar; bar_off; spout
# 14                                bar; bar_off; spout
# 15                                bar; bar_off; spout
# 16                                bar; bar_off; spout
# 17                    bar; bar_off; spout; hold_start
# 18                                bar; bar_off; spout
# 19            bar; bar_off; spout; reward_delay_timer
# 20                                bar; bar_off; spout
# 21                  bar; bar_off; spout; US_end_timer
# 22  bar; bar_off; spout; button_release; US_end_timer
# 23                  bar; bar_off; spout; US_end_timer
# 24                  bar; bar_off; spout; US_end_timer
# 25                  bar; bar_off; spout; US_end_timer
#
#                                            conditions
# 0                                         free_reward
# 1                                         free_reward
# 2                                         free_reward
# 3   error bar_off; reward bar_off; error free; rew...
# 4   error bar_off; reward bar_off; error free; rew...
# 5   s_nogo_sham; s_nogo_cs_onset; s_go_sham; s_go_...
# 6   s_nogo_sham; s_nogo_cs_onset_2; s_nogo_cs_onse...
# 7   s_nogo_sham; s_nogo_cs_onset_2; s_nogo_cs_onse...
# 8   error bar_off; reward bar_off; error free; rew...
# 9   error bar_off; reward bar_off; error free; rew...
# 10  error bar_off; reward bar_off; error free; rew...
# 11                                        free_reward
# 12                                        free_reward
# 13                                        free_reward
# 14                                        free_reward
# 15                                        free_reward
# 16                                        free_reward
# 17  free_reward_timer; reward spout cued; reward b...
# 18                                                NaN
# 19  delayed reward spout cued; delayed reward spou...
# 20  free_reward; Go_water spout success; Go_air sp...
# 21  US_end_timer; water_on; water success; busy_wi...
# 22  US_end_timer; water by bar_off; water by spout...
# 23  US_end_timer; water_on; water by bar_off; wate...
# 24  US_end_timer; break_after_abort; water_on; wat...
# 25  US_end_timer; break_after_abort; water_on; wat...

# %% [markdown]
# ### Create an experiment object
#
# This will include all the pycontrol files present in the folder_path directory (do not include subdirectories)

# %%
# Folder of a full experimental batch, all animals included

# Load all raw text sessions in the indicated folder or a sessions.pkl file
# if already existing in folder_path
exp_cohort = Experiment(pycontrol_dir)

# Only use if the Experiment cohort as been processed by trials before
# TODO: assess whether this can be removed or not
exp_cohort.by_trial = True
# Out:
# Saved sessions loaded from: sessions.pkl

# %% [markdown]
# ### Perform extraction of behavioural information by trial

# %%
# Process the whole experimental folder by trials
exp_cohort.process_exp_by_trial(trial_window, timelim, tasksfile)

# Save the file as sessions.pkl in folder_path
exp_cohort.save()
# Out:
# No event  'spout'  found:  318 2022-12-02 11:28:39 reaching_go_spout_bar_nov22
# saved \\ettin\Magill_Lab\Julien\Data\head-fixed\test_folder\delayed_go\pycontrol\sessions.pkl

# %% [markdown]
# ### Match with photometry, videos, and DeepLabCut files

# %%
# Find if there is a matching photometry file:
exp_cohort.match_sessions_to_files(photometry_dir, ext='ppd')

# rsync synchronization pulses matching between behaviour and photometry
exp_cohort.sync_photometry_files(2)

# Find matching videos
exp_cohort.match_sessions_to_files(video_dir, ext='mp4')

# FInd matching DeepLabCut outputs files
exp_cohort.match_sessions_to_files(video_dir, ext='h5', verbose=True)

exp_cohort.save()

# %% [markdown]
# ### Find Videos to score on DeepLabCut

# %%
from copy import deepcopy

exp_subset = deepcopy(exp_cohort)

# %%
tasks = set([session.task_name for session in exp_subset.sessions])
tasks =  list(tasks)
tasks
# Out:
# ['reaching_go_spout_bar_dual_dec22',
#  'reaching_go_spout_bar_dual_all_reward_dec22']

# %%
exp_subset.sessions[0].files
# Out:
# {'ppd': ['\\\\ettin\\Magill_Lab\\Julien\\Data\\head-fixed\\test_folder\\delayed_go\\pyphotometry\\delayed_go_dual_2022\\JC317L-2022-12-15-150039.ppd'],
#  'mp4': ['\\\\ettin\\Magill_Lab\\Julien\\Data\\head-fixed\\videos\\12-15-22_14-54-57.000_JC317L_Rig_3_Down.mp4',
#   '\\\\ettin\\Magill_Lab\\Julien\\Data\\head-fixed\\videos\\12-15-22_14-54-57.000_JC317L_Rig_3_Side.mp4'],
#  'h5': ['\\\\ettin\\Magill_Lab\\Julien\\Data\\head-fixed\\videos\\12-15-22_14-54-57.000_JC317L_Rig_3_SideDLC_resnet50_side_2_hands_newobjAug26shuffle1_700000.h5']}

# %%
exp_subset.sessions = [session for session in exp_subset.sessions if 
    (len(session.files['ppd']) > 0) and
    (len(session.files['h5']) > 0)]

len(exp_subset.sessions)
# Out:
# 3

# %% [markdown]
# first rough export of videos to score on DeepLabcut, will need to be refined

# %% [markdown]
# ### Define conditions and groups for extraction

# %%
# Defime each trial type as a dictionary of conditions to be met
# Defime each trial type as a dictionary of conditions to be met
conditions_dict1 = {'trigger': 'hold_for_water', 'success': True, 'valid': True, 
    'hold_timer': True, 'water by bar_off': False, 'water for free': False} 
conditions_dict2 = {'trigger': 'hold_for_water', 'valid': True, 'hold_timer': False,
    'break_after_abort': True, 'US_end_timer': False, 'success': False, 'button_press': False}

# conditions_dict2 = {'trigger': 'hold_for_water', 'spout':False, 'valid': True, 'busy_win_timer': False, 'button_press': False}

# Aggregate all condition dictionaries in a list
condition_list = [conditions_dict1, conditions_dict2]
# Aliases for conditions
cond_aliases = ['Go - hold', 'Go - aborted']
# Groups as a list of lists
# groups = [[280, 281, 282, 289],[295, 282, 284, 285, 292, 297]]
groups = None

# Window to exctract (in ms)

# %% [markdown]
# ### Set DeepLabCut bodyparts to compute paws centroids

# %%
# Name of the labelled body parts from both upper limbs
# The bodyparts from which we draw here are user-defined
# when creating a new DeepLabCut project (config.yaml)

L_paw_parts  = ['MCP II', 'MCP III', 'MCP IV', 'MCP V', 'IP II', 'IP III', \
    'IP IV', 'IP V', 'tip II', 'tip III', 'tip IV', 'tip V'] 

R_paw_parts = ['r MCP II', 'r MCP III', 'r MCP IV', 'r MCP V', 'r IP II', \
    'r IP III', 'r IP IV', 'r IP V', 'r tip II', 'r tip III', 'r tip IV', 'r tip V']

names_of_ave_regions = ['Left_paw','Right_paw']

# %% [markdown]
# ### Extract DeepLabCut trials and create a Continuous_Dataset

# %%
# !pip install tables
# Out:
# Collecting tables
#   Downloading tables-3.8.0-cp38-cp38-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 1.1 MB/s eta 0:00:00
# Collecting numexpr>=2.6.2
#   Downloading numexpr-2.8.4-cp38-cp38-win_amd64.whl (92 kB)
#      ---------------------------------------- 92.7/92.7 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\phar0732\anaconda3\envs\trialexp\lib\site-packages (from tables) (21.3)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting cython>=0.29.21
#   Downloading Cython-0.29.33-py2.py3-none-any.whl (987 kB)
#      -------------------------------------- 987.3/987.3 kB 2.5 MB/s eta 0:00:00
# Collecting blosc2~=2.0.0
#   Downloading blosc2-2.0.0-cp38-cp38-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in c:\users\phar0732\anaconda3\envs\trialexp\lib\site-packages (from tables) (1.23.2)
# Collecting msgpack
#   Downloading msgpack-1.0.4-cp38-cp38-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.2/62.2 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\phar0732\anaconda3\envs\trialexp\lib\site-packages (from packaging->tables) (3.0.9)
# Installing collected packages: py-cpuinfo, msgpack, numexpr, cython, blosc2, tables
# Successfully installed blosc2-2.0.0 cython-0.29.33 msgpack-1.0.4 numexpr-2.8.4 py-cpuinfo-9.0.0 tables-3.8.0

# %%
cont_dataset = exp_subset.get_deeplabcut_groups(
        groups = None,
        conditions_list = condition_list,
        cond_aliases = cond_aliases,
        when='all', 
        task_names = tasks,
        bodyparts_to_ave = [L_paw_parts, R_paw_parts],
        names_of_ave_regions = ['Left_paw','Right_paw'], 
        bodyparts_to_store = ['spout', 'jaw', 'ear', 'tongue', 'tip III',  'IP III', 'MCP III'],
        normalize_between = ['Left_paw', 'spout'],
        bins_nb = 100,
        three_dims = False, 
        p_thresh = 0.9,
        camera_fps = 100, # not yet functional
        camera_keyword = 'Side', 
        trig_on_ev = None, 
        verbose = True)
# Out:
# Processing subject 317 at: 2022-12-15 14:55:30
# Successfully loaded DLC file: 12-15-22_14-54-57.000_JC317L_Rig_3_SideDLC_resnet50_side_2_hands_newobjAug26shuffle1_700000.h5
# No trial in any condition for subject 317 at: 2022-12-15 14:55:30
# Processing subject 317 at: 2022-12-15 15:00:40
# Successfully loaded DLC file: 12-15-22_15-00-26.000_JC317L_Rig_3_SideDLC_resnet50_side_2_hands_newobjAug26shuffle1_700000.h5
# condition 0 trials: 15
# condition 1 trials: 22
# Processing subject 317 at: 2022-12-15 16:02:18
# Successfully loaded DLC file: 12-15-22_16-01-55.000_JC317L_Rig_3_SideDLC_resnet50_side_2_hands_newobjAug26shuffle1_700000.h5
# condition 0 trials: 3

# %% [markdown]
# ### Save DLC Dataset

# %%
folder_path = r'C:\Users\phar0732\Documents\GitHub\trialexp\sample_data\outputs'

cont_dataset.save(folder_path, 'DLC_dataset_delayed_317')
# Out:
# Dataset saved in C:\Users\phar0732\Documents\GitHub\trialexp\sample_data\outputs\DLC_dataset_delayed_317.pkl
# data size is 6.5919342041015625 Mb

# %% [markdown]
# ### Reload a pre-existing dataset

# %%
dataset_full_path = r'C:\Users\phar0732\Documents\GitHub\pycontrol_share\outputs\DLC_dataset_opto_continuous_full.pkl'
cont_dataset = load_dataset(dataset_full_path)

# %% [markdown]
# Metadata preview

# %%
cont_dataset.metadata_df
# Out:
#     subject_ID            datetime  \
# 0          317 2022-12-15 15:00:40
# 1          317 2022-12-15 15:00:40
# 2          317 2022-12-15 15:00:40
# 3          317 2022-12-15 15:00:40
# 4          317 2022-12-15 15:00:40
# 5          317 2022-12-15 15:00:40
# 6          317 2022-12-15 15:00:40
# 7          317 2022-12-15 15:00:40
# 8          317 2022-12-15 15:00:40
# 9          317 2022-12-15 15:00:40
# 10         317 2022-12-15 15:00:40
# 11         317 2022-12-15 15:00:40
# 12         317 2022-12-15 15:00:40
# 13         317 2022-12-15 15:00:40
# 14         317 2022-12-15 15:00:40
# 15         317 2022-12-15 15:00:40
# 16         317 2022-12-15 15:00:40
# 17         317 2022-12-15 15:00:40
# 18         317 2022-12-15 15:00:40
# 19         317 2022-12-15 15:00:40
# 20         317 2022-12-15 15:00:40
# 21         317 2022-12-15 15:00:40
# 22         317 2022-12-15 15:00:40
# 23         317 2022-12-15 15:00:40
# 24         317 2022-12-15 15:00:40
# 25         317 2022-12-15 15:00:40
# 26         317 2022-12-15 15:00:40
# 27         317 2022-12-15 15:00:40
# 28         317 2022-12-15 15:00:40
# 29         317 2022-12-15 15:00:40
# 30         317 2022-12-15 15:00:40
# 31         317 2022-12-15 15:00:40
# 32         317 2022-12-15 15:00:40
# 33         317 2022-12-15 15:00:40
# 34         317 2022-12-15 15:00:40
# 35         317 2022-12-15 15:00:40
# 36         317 2022-12-15 15:00:40
# 37         317 2022-12-15 16:02:18
# 38         317 2022-12-15 16:02:18
# 39         317 2022-12-15 16:02:18
#
#                                       task_name  condition_ID  trial_nb  \
# 0              reaching_go_spout_bar_dual_dec22             0         3
# 1              reaching_go_spout_bar_dual_dec22             0        14
# 2              reaching_go_spout_bar_dual_dec22             0        49
# 3              reaching_go_spout_bar_dual_dec22             0        61
# 4              reaching_go_spout_bar_dual_dec22             0       132
# 5              reaching_go_spout_bar_dual_dec22             0       142
# 6              reaching_go_spout_bar_dual_dec22             0       147
# 7              reaching_go_spout_bar_dual_dec22             0       152
# 8              reaching_go_spout_bar_dual_dec22             0       157
# 9              reaching_go_spout_bar_dual_dec22             0       164
# 10             reaching_go_spout_bar_dual_dec22             0       167
# 11             reaching_go_spout_bar_dual_dec22             0       171
# 12             reaching_go_spout_bar_dual_dec22             0       181
# 13             reaching_go_spout_bar_dual_dec22             0       188
# 14             reaching_go_spout_bar_dual_dec22             0       190
# 15             reaching_go_spout_bar_dual_dec22             1         1
# 16             reaching_go_spout_bar_dual_dec22             1         6
# 17             reaching_go_spout_bar_dual_dec22             1        16
# 18             reaching_go_spout_bar_dual_dec22             1        17
# 19             reaching_go_spout_bar_dual_dec22             1        18
# 20             reaching_go_spout_bar_dual_dec22             1        22
# 21             reaching_go_spout_bar_dual_dec22             1        23
# 22             reaching_go_spout_bar_dual_dec22             1        29
# 23             reaching_go_spout_bar_dual_dec22             1        30
# 24             reaching_go_spout_bar_dual_dec22             1        37
# 25             reaching_go_spout_bar_dual_dec22             1        53
# 26             reaching_go_spout_bar_dual_dec22             1        66
# 27             reaching_go_spout_bar_dual_dec22             1        67
# 28             reaching_go_spout_bar_dual_dec22             1        78
# 29             reaching_go_spout_bar_dual_dec22             1        82
# 30             reaching_go_spout_bar_dual_dec22             1        94
# 31             reaching_go_spout_bar_dual_dec22             1       100
# 32             reaching_go_spout_bar_dual_dec22             1       123
# 33             reaching_go_spout_bar_dual_dec22             1       137
# 34             reaching_go_spout_bar_dual_dec22             1       148
# 35             reaching_go_spout_bar_dual_dec22             1       153
# 36             reaching_go_spout_bar_dual_dec22             1       174
# 37  reaching_go_spout_bar_dual_all_reward_dec22             0         8
# 38  reaching_go_spout_bar_dual_all_reward_dec22             0        11
# 39  reaching_go_spout_bar_dual_all_reward_dec22             0        28
#
#     session_nb  group_ID  keep  trial_ID
# 0           24         0  True         0
# 1           24         0  True         1
# 2           24         0  True         2
# 3           24         0  True         3
# 4           24         0  True         4
# 5           24         0  True         5
# 6           24         0  True         6
# 7           24         0  True         7
# 8           24         0  True         8
# 9           24         0  True         9
# 10          24         0  True        10
# 11          24         0  True        11
# 12          24         0  True        12
# 13          24         0  True        13
# 14          24         0  True        14
# 15          24         0  True        15
# 16          24         0  True        16
# 17          24         0  True        17
# 18          24         0  True        18
# 19          24         0  True        19
# 20          24         0  True        20
# 21          24         0  True        21
# 22          24         0  True        22
# 23          24         0  True        23
# 24          24         0  True        24
# 25          24         0  True        25
# 26          24         0  True        26
# 27          24         0  True        27
# 28          24         0  True        28
# 29          24         0  True        29
# 30          24         0  True        30
# 31          24         0  True        31
# 32          24         0  True        32
# 33          24         0  True        33
# 34          24         0  True        34
# 35          24         0  True        35
# 36          24         0  True        36
# 37          25         0  True        37
# 38          25         0  True        38
# 39          25         0  True        39

# %% [markdown]
# ### Optional methods
#
# - Implementation of these optional filtering options is first understood as removing subjects, groups, conditions...
# - It is a non-permanent way of discarding elements for analysis
# - It is based on a "keep" column in the metadata that is True by default and set to False with the filtering function.
# - At anytime, <trial_dataset>.filter_reset() can be called to re-include all the elements in the analysis (set all "keep" to True)
# - Comment or uncomment lines and fill the lists according to your needs

# %%
# Get a list of the groups
cont_dataset.get_groups()
# Get a list of the variables
cont_dataset.get_col_names()

# reset previous filtering of the dataset
cont_dataset.filter_reset()

# exclude some conditions by IDs
cont_dataset.filter_conditions([])

# exclude some groups by IDs
cont_dataset.filter_groups([])

# exclude some subjects
cont_dataset.filter_subjects([0, 1])
#     subjects_IDs_to_exclude = [289, 290, 293, 294, 295, 299, 301, 303, 304, 305, 306])

# filter subjects/sessions with less than x trials (for each condition separately)
cont_dataset.filter_min(min_trials = 1)

# To remove subjects who do not have trials
# in all the conditions, if called after filter_min(),
# will discard any subject who do not have the minimum number
# of trials in all the conditions

# cont_dataset.filter_if_not_in_all_cond()

# %% [markdown]
# ### Plot DeepLabCut position by conditions

# %%
### Plot the photometry by condition
cont_dataset.set_trial_window([-2, 6], 's')
cont_dataset.set_conditions(condition_list, cond_aliases)
cont_dataset.lineplot(
    vars = ['Left_paw_x','Left_paw_y'],
    time_lim = [-2000, 6000],
    time_unit = 'milliseconds',
    error = True,
    ylim = [[-0.05, 1],[-0.05, 1]], #[[-0.1, 1]],#,[-0.005, 0.007]],#[[-0.001, 0.0011],[-0.001, 0.0011]],
    colormap = 'jet',
    legend = True,
    plot_subjects = True,
    plot_groups = True,
    figsize = (15,5),
    dpi = 100,
    verbose = False)

# Return a count of overall number of trials
cont_dataset.metadata_df['keep'].value_counts()
# Out:
# True    40
# Name: keep, dtype: int64

# %% [markdown]
# Example line to count how many trials are included for subject 307

# %%
cont_dataset.metadata_df.keep[cont_dataset.metadata_df.subject_ID == 317].value_counts()
# Out:
# True    40
# Name: keep, dtype: int64
