# %% [markdown]
# # reaching_go_spout_nov22

# %% [markdown]
# Quick analysis of instrumental reaching

# %%
# allow for automatic reloading of classes and function when updating the code
# %load_ext autoreload
# %autoreload 2 

# Import Session and Experiment class with helper functions
from trialexp.process.data_import import *
from trialexp.process.pycontrol_utils import *
import seaborn as sns

# %% [markdown]
# ### Variables
# - This is where you specify your variable for folders etc.

# %%
# Only analyze an experimental session

pycontrol_dir = r'C:\Users\phar0732\Documents\GitHub\trialexp\sample_data\pycontrol\reaching_go_spout'

# Filename only used for single file analysis, which is now possible but not the default mode
filename = r'\kms064-2023-02-06-094431.txt'

filepath = r'C:\Users\phar0732\Documents\GitHub\trialexp\sample_data\pycontrol\kms064-2023-02-02-111805.txt'

tasks_params_file = r'C:\Users\phar0732\Documents\GitHub\trialexp\params\tasks_params.csv'

trial_window = [-2000, 4000]

# %% [markdown]
# ### Create an experiment object

# %% [markdown]
# ### Get the data and metadata about behaviour with old methds

# %%
#Create experiment object
exp_cohort = Experiment(pycontrol_dir, update = True) #TODO

#Get experiment processed by trial
exp_cohort.process_exp_by_trial(trial_window = trial_window, tasksfile = tasks_params_file)

print(f'\nNumber of sessions: {len(exp_cohort.sessions)}')
# Out:
# Number of sessions: 41

# %%
# Defime each trial type as a dictionary of conditions to be met
conditions_dict1 = {'success': True}

# conditions_dict2 = {'trigger': 'hold_for_water', 'success': False, 'hold_timer': True}

conditions_dict2 = {'success': False}

# conditions_dict2 = {'trigger': 'hold_for_water', 'spout':False, 'valid': True, 'busy_win_timer': False, 'button_press': False}

# Aggregate all condition dictionaries in a list
conditions_list = [conditions_dict1, conditions_dict2]
# Aliases for conditions
cond_aliases = ['Hit', 'Miss']
# Groups as a list of lists
# groups = [[280, 281, 282, 289],[295, 282, 284, 285, 292, 297]]
groups = None

# %%
import copy
from matplotlib.pyplot import show

for session_idx, session in enumerate(exp_cohort.sessions):
    # make a copy of the experiment object
    exp_subset = copy.deepcopy(exp_cohort)
    # turn into an experiment with only one session
    exp_subset.sessions = [exp_subset.sessions[session_idx]]
    # extract an event dataset
    behav_events = exp_subset.behav_events_to_dataset(conditions_list = None, cond_aliases = None, groups = None)
    # Print some info about the session
    print(f'\nSession: {session.subject_ID} {session.datetime} {session.task_name}')
    print(f'Number of trials: {len(behav_events.data)}')
    # plot the raster
    behav_events.plot_raster(keys=['bar_off_trial_time','spout_trial_time','US_end_timer_trial_time'], separate=True)
    show()
# Out:
# Session: 58 2023-01-26 10:36:50 reaching_go_spout_nov22
# Number of trials: 35
# Session: 58 2023-01-26 10:48:22 reaching_go_spout_nov22
# Number of trials: 21
# Session: 60 2023-01-26 11:06:54 reaching_go_spout_nov22
# Number of trials: 67
# Session: 61 2023-01-26 11:48:19 reaching_go_spout_nov22
# Number of trials: 79
# Session: 62 2023-01-26 12:16:21 reaching_go_spout_nov22
# Number of trials: 36
# Session: 63 2023-01-26 12:34:10 reaching_go_spout_nov22
# Number of trials: 70
# Session: 64 2023-01-26 12:54:16 reaching_go_spout_nov22
# Number of trials: 60
# Session: 58 2023-01-27 09:37:46 reaching_go_spout_nov22
# Number of trials: 79
# Session: 60 2023-01-27 10:31:49 reaching_go_spout_nov22
# Number of trials: 58
# Session: 61 2023-01-27 10:59:49 reaching_go_spout_nov22
# Number of trials: 87
# Session: 62 2023-01-27 11:37:03 reaching_go_spout_nov22
# Number of trials: 51
# Session: 63 2023-01-27 12:02:56 reaching_go_spout_nov22
# Number of trials: 42
# Session: 64 2023-01-27 12:20:55 reaching_go_spout_nov22
# Number of trials: 70
# Session: 58 2023-01-27 16:43:13 reaching_go_spout_nov22
# Number of trials: 82
# Session: 60 2023-01-27 17:09:48 reaching_go_spout_nov22
# Number of trials: 42
# Session: 58 2023-01-30 10:10:44 reaching_go_spout_nov22
# Number of trials: 46
# Session: 61 2023-01-30 10:34:13 reaching_go_spout_nov22
# Number of trials: 61
# Session: 60 2023-01-30 11:04:08 reaching_go_spout_nov22
# Number of trials: 57
# Session: 62 2023-01-30 11:35:50 reaching_go_spout_nov22
# Number of trials: 69
# Session: 63 2023-01-30 12:21:24 reaching_go_spout_nov22
# Number of trials: 57
# Session: 61 2023-01-30 17:22:48 reaching_go_spout_nov22
# Number of trials: 74
# Session: 63 2023-01-30 17:52:11 reaching_go_spout_nov22
# Number of trials: 100
# Session: 58 2023-01-31 10:55:41 reaching_go_spout_nov22
# Number of trials: 69
# Session: 60 2023-01-31 11:45:27 reaching_go_spout_nov22
# Number of trials: 36
# Session: 61 2023-01-31 11:52:06 reaching_go_spout_nov22
# Number of trials: 63
# Session: 62 2023-01-31 12:30:45 reaching_go_spout_nov22
# Number of trials: 51
# Session: 63 2023-01-31 12:30:46 reaching_go_spout_nov22
# Number of trials: 56
# Session: 61 2023-02-01 10:07:43 reaching_go_spout_nov22
# Number of trials: 53
# Session: 60 2023-02-01 10:17:37 reaching_go_spout_nov22
# Number of trials: 59
# Session: 62 2023-02-01 10:17:37 reaching_go_spout_nov22
# Number of trials: 25
# Session: 60 2023-02-01 10:38:49 reaching_go_spout_nov22
# Number of trials: 15
# Session: 62 2023-02-01 10:38:49 reaching_go_spout_nov22
# Number of trials: 39
# Session: 63 2023-02-01 11:25:43 reaching_go_spout_nov22
# Number of trials: 64
# Session: 60 2023-02-02 10:19:08 reaching_go_spout_nov22
# Number of trials: 92
# Session: 62 2023-02-02 10:19:08 reaching_go_spout_nov22
# Number of trials: 47
# Session: 61 2023-02-02 12:13:59 reaching_go_spout_nov22
# Number of trials: 66
# Session: 60 2023-02-03 14:53:35 reaching_go_spout_nov22
# Number of trials: 118
# Session: 62 2023-02-03 14:58:23 reaching_go_spout_nov22
# Number of trials: 45
# Session: 60 2023-02-06 09:54:01 reaching_go_spout_nov22
# Number of trials: 44
# Session: 62 2023-02-06 11:24:51 reaching_go_spout_nov22
# Number of trials: 20
# Session: 60 2023-02-07 12:48:52 reaching_go_spout_nov22
# Number of trials: 65

# %% [markdown]
# # Analyze rewards

# %%
df_reward = df_events[df_events.event_name == 'US_delay_timer']

# %% [markdown]
# ## Analyze the first spout time

# %%
df_first_spout = df_events[(df_events.state=='waiting_for_spout') & (df_events.event_name =='spout')].copy()
df_trial_start = df_events[(df_events.state=='waiting_for_spout') & (df_events.event_name =='state_change')].copy()
# assert len(df_first_spout) == len(df_trial_start)

df_first_spout['time_first_spout'] = (df_first_spout.time.values - df_trial_start.time.values)
df_first_spout.trial_number = df_first_spout.trial_number.astype(str) #hack to force seaborn to treat this as categoric variable
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\phar0732\Documents\GitHub\trialexp\notebooks\noncanonical\nb20230209_104000_teris_behav_extract_julien_photo.ipynb Cell 11 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/phar0732/Documents/GitHub/trialexp/notebooks/noncanonical/nb20230209_104000_teris_behav_extract_julien_photo.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> df_trial_start = df_events[(df_events.state=='waiting_for_spout') & (df_events.event_name =='state_change')].copy()
#       <a href='vscode-notebook-cell:/c%3A/Users/phar0732/Documents/GitHub/trialexp/notebooks/noncanonical/nb20230209_104000_teris_behav_extract_julien_photo.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> # assert len(df_first_spout) == len(df_trial_start)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/phar0732/Documents/GitHub/trialexp/notebooks/noncanonical/nb20230209_104000_teris_behav_extract_julien_photo.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> df_first_spout['time_first_spout'] = (df_first_spout.time.values - df_trial_start.time.values)
#       <a href='vscode-notebook-cell:/c%3A/Users/phar0732/Documents/GitHub/trialexp/notebooks/noncanonical/nb20230209_104000_teris_behav_extract_julien_photo.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> df_first_spout.trial_number = df_first_spout.trial_number.astype(str)
#
# ValueError: operands could not be broadcast together with shapes (31,) (124,)
